# %% [markdown]
# # Fooocus Realistic Edition на Google Colab
#
# Этот ноутбук запускает Fooocus с preset **realistic** для генерации реалистичных изображений.
#
# **Модель:** realisticStockPhoto_v20.safetensors
#
# ## Инструкция:
# 1. Нажмите на кнопку "Runtime" → "Change runtime type"
# 2. Выберите "GPU" в качестве Hardware accelerator
# 3. Запустите ячейку ниже (Shift+Enter)
# 4. Дождитесь завершения установки и запуска
# 5. Используйте публичную ссылку для доступа к интерфейсу

# %%
# Установка зависимостей и запуск Fooocus с preset realistic
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# Запуск с preset realistic для реалистичных изображений
# !python entry_with_update.py --share --always-high-vram --preset realistic
